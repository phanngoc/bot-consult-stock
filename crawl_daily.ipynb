# %%
from imp import reload

import crawl
reload(crawl)


tn = crawl.CrawlCafeF()
tn.run(daily=True)

tn = crawl.CrawlThanhNien()
tn.run(daily=True)
# Out:
# crawl_html https://cafef.vn/timelinelist/18831/1.chn {}
# Title: Một doanh nghiệp xăng dầu lùi thời hạn trả lãi trái phiếu, cổ phiếu liên tục tăng kịch trần
# Link: /mot-doanh-nghiep-xang-dau-lui-thoi-han-tra-lai-trai-phieu-co-phieu-lien-tuc-tang-kich-tran-188230907154359211.chn
# get_page_detail https://cafef.vn/mot-doanh-nghiep-xang-dau-lui-thoi-han-tra-lai-trai-phieu-co-phieu-lien-tuc-tang-kich-tran-188230907154359211.chn {}
# create_article /mot-doanh-nghiep-xang-dau-lui-thoi-han-tra-lai-trai-phieu-co-phieu-lien-tuc-tang-kich-tran-188230907154359211.chn 0
# isDup 1
# crawl_html https://cafef.vn/timelinelist/18831/2.chn {}
# Title: Doanh nghiệp thủy điện ở miền Trung làm ăn ra sao?
# Link: /doanh-nghiep-thuy-dien-o-mien-trung-lam-an-ra-sao-188230907131237261.chn
# get_page_detail https://cafef.vn/doanh-nghiep-thuy-dien-o-mien-trung-lam-an-ra-sao-188230907131237261.chn {}
# create_article /doanh-nghiep-thuy-dien-o-mien-trung-lam-an-ra-sao-188230907131237261.chn 0
# isDup 1
# ...

# %%
import crawl
reload(crawl)

driver = crawl.create_driver()
driver2 = crawl.create_driver()

vs = crawl.CrawlVietStock(driver=driver, driver2=driver2)
vs.run(fresh_start=True, daily=False)
# Out:
# CrawlVietStock::__init__ <selenium.webdriver.chrome.webdriver.WebDriver (session="d7e04690727658a116001003943705ee")> 20
# create_driver::driver: <selenium.webdriver.chrome.webdriver.WebDriver (session="d7e04690727658a116001003943705ee")>
# CSV file 'backup_title_url.csv' has been truncated.
# headings_a:len 10
# heading_elem <selenium.webdriver.remote.webelement.WebElement (session="d7e04690727658a116001003943705ee", element="8421DCEE4451B0CC3A9722844272FF16_element_134")>
# Title: Cổ đông ngoại Singapore mua thêm 2.5 triệu cp KDC
# Link: https://vietstock.vn/2023/09/co-dong-ngoai-singapore-mua-them-25-trieu-cp-kdc-739-1106155.htm
# datePublish 2 giờ trước 2023-09-09 09:20:04.794944
# create_article:update https://vietstock.vn/2023/09/co-dong-ngoai-singapore-mua-them-25-trieu-cp-kdc-739-1106155.htm
# heading_elem <selenium.webdriver.remote.webelement.WebElement (session="d7e04690727658a116001003943705ee", element="8421DCEE4451B0CC3A9722844272FF16_element_135")>
# ...

# %%
# https://www.geeksforgeeks.org/multithreading-or-multiprocessing-with-python-and-selenium/
