# %% [markdown]
# # zero shot classification with vinai/phobert-base
# Đang try thử , chắc dùng model này để dự đoán từ nào gần với từ cần check nhất. (có vẻ khó thành công do dữ liệu quá ít)

# %%
# !pip install textract
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 3.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 7.0 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 6.9 MB/s eta 0:00:0000:010:01m
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 8.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 8.7 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 4.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# https://data.vdsc.com.vn/vi/Com_Document/VNM/

# %%
from openai.embeddings_utils import cosine_similarity, get_embedding
from dotenv import load_dotenv
import openai
import os

load_dotenv()

apiKey = os.getenv('OPENAI_API_KEY')
openai.api_key = apiKey
print(apiKey)

# parameters
EMBEDDING_MODEL = "text-embedding-ada-002"
# Out:
# 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
# ...

# %%
path = '1517456934-51f84d5d6cb5ceae2465a7da470fc533ac4830e4776cc0fd3aa76c0fe7537c8e.pdf'
import textract
import tiktoken

# Extract the raw text from each PDF using textract
text = textract.process(path, method='pdfminer').decode('utf-8')
clean_text = text.replace("  ", " ").replace("\n", "; ").replace(';',' ')
print(clean_text)

encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
encoding.encode("tiktoken is great!")

test = [
    """Bộ Tài chính muốn thu phí khí thải. Là khoản thu mới nhằm bảo vệ môi trường, phí khí thải dự kiến giúp ngân sách có thêm 1.200 tỷ đồng một năm, theo Bộ Tài chính.
Dự thảo Nghị định quy định phí bảo vệ môi trường với khí thải đang được Bộ Tài chính lấy ý kiến các bộ, ngành, địa phương, doanh nghiệp.
Cơ quan này cho biết cùng với sự phát triển của kinh tế, chất lượng không khí tại các thành phố lớn, khu công nghiệp, làng nghề Việt Nam đang ngày càng suy giảm, tác hại nghiêm trọng đến sức khoẻ cộng đồng, thiệt hại cho nền kinh tế, đe doạ đến môi trường."""
]

t = encoding.encode(test[0])
print(t)

# Example prompt - 
document = '<document>'
template_prompt=f'''Lấy các mẫu thông tin quan trọng từ tài liệu sau đây.
Nếu phần thông tin cụ thể không có, hãy xuất ra "Not specified".
Sử dụng định dạng sau:\n0. Tài sản dài hạn\n1. Tỷ suất lợi nhuận\n2. Tên công ty\n3. Lợi nhuận\n\nTài liệu: \"\"\"{document}\"\"\"\n\n'''

print(template_prompt)
# Out:
# Lấy các mẫu thông tin quan trọng từ tài liệu sau đây.
# Nếu phần thông tin cụ thể không có, hãy xuất ra "Not specified".
# Sử dụng định dạng sau:
# 0. Tài sản dài hạn
# 1. Tỷ suất lợi nhuận
# 2. Tên công ty
# 3. Lợi nhuận
#
# Tài liệu: """<document>"""

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead, GPT2Tokenizer, GPT2LMHeadModel

# tokenizer = AutoTokenizer.from_pretrained("NlpHUST/gpt2-vietnamese")
# model = AutoModelWithLMHead.from_pretrained('NlpHUST/gpt2-vietnamese')

# Load model directly
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")
model = AutoModelForMaskedLM.from_pretrained("vinai/phobert-base")
# Out:
# ...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...

# %%
from transformers import AutoTokenizer, RobertaForMaskedLM
import torch

text = """Mã cổ phiếu nào ở câu này:
    "Dự đoán giá cổ phiếu VIC trong 3 ngày tới ?" <mask><mask><mask><mask>
"""
inputs = tokenizer(text, return_tensors="pt")

with torch.no_grad():
    logits = model(**inputs).logits

# retrieve index of <mask>
mask_token_index = (inputs.input_ids == tokenizer.mask_token_id)[0].nonzero(as_tuple=True)[0]

predicted_token_id = logits[0, mask_token_index].argmax(axis=-1)
keyword_predicted = tokenizer.decode(predicted_token_id)
print(keyword_predicted)

# labels = tokenizer("The capital of France is Paris.", return_tensors="pt")["input_ids"]
# # mask labels of non-<mask> tokens
# labels = torch.where(inputs.input_ids == tokenizer.mask_token_id, labels, -100)

# outputs = model(**inputs, labels=labels)
# round(outputs.loss.item(), 2)
# Out:
# Giá giá giá.

# %%
text1 = """Nguyễn Đức Trung, 31 tuổi, cựu thượng úy cảnh sát giao thông Công an tỉnh Vĩnh Phúc, khai mắc nợ nhiều nên bắt cóc bé trai ở Hà Nội, tống tiền 15 tỷ đồng"""
text2 = """Who won the NBA championship? And who was the MVP? Tell me a bit about the last game"""
t_embed = get_embedding(text2, engine=EMBEDDING_MODEL)
print(len(t_embed), t_embed)
# Out:
# 1536 [-0.001919984701089561, -0.016388889402151108, 0.01105559803545475, -0.015661051496863365, -0.03272758424282074, 0.0291385930031538, 0.003541932674124837, -0.011375595815479755, -0.03295346349477768, -0.016225753352046013, 0.034835800528526306, 0.02070571854710579, -0.012266568839550018, -0.0014078319072723389, 0.031146420165896416, -0.0228766817599535, 0.029665647074580193, 0.00125253910664469, 0.009850902482867241, -0.01800769940018654, 0.0008792087319307029, -0.011118343099951744, -0.006845436058938503, -0.01744299940764904, 0.01995278336107731, -0.0057379938662052155, 0.003780362196266651, -0.009907372295856476, 0.002901937812566757, -0.02773311361670494, 0.018170835450291634, -0.01213480532169342, -0.013013229705393314, -0.016727710142731667, -0.025386465713381767, -0.005948188249021769, 0.006167794112116098, -0.01088618766516447, 0.016865748912096024, 0.0015325368149206042, 0.013577931560575962, 0.013828909955918789, -0.0026070380117744207, -0.0030431130435317755, -0.00943
# ...

# %%
from sklearn.metrics import PrecisionRecallDisplay

from underthesea import word_tokenize
import pandas as pd

def token_sent(sentences = []):
    results = []
    for sentence in sentences:
        texts = word_tokenize(sentence, format="text").split()
        results.append(texts)
    return results

def label_score(review_embedding, label_embeddings):
    return cosine_similarity(review_embedding, label_embeddings[1]) - cosine_similarity(review_embedding, label_embeddings[0])
# Out:
# x 0.00022690021659588222
# t thông tin chứng khoán tiêu cực

# %%
def remove_work_notin_tokenizer(text, tokenizer):
    text = text.lower()
    words = token_sent([text])[0]
    print(text, words)
    vocab = list(tokenizer.get_vocab())
    print('vocab', vocab)
    list_token_valid = [word for word in words if word in vocab]
    return list_token_valid

remove_work_notin_tokenizer("đây là báo cáo tài chính của công ty vinamilk", tokenizer)
# Out:
# đây là báo cáo tài chính của công ty vinamilk ['đây', 'là', 'báo_cáo', 'tài_chính', 'của', 'công_ty', 'vinamilk']
# ...

# %%
tokenizer.add_special_tokens({'pad_token': '[PAD]'})

# Split a text into smaller chunks of size n, preferably ending at the end of a sentence
def create_chunks(text, n, tokenizer):
    tokens = tokenizer.encode(text)
    """Yield successive n-sized chunks from text."""
    i = 0
    while i < len(tokens):
        # Find the nearest end of sentence within a range of 0.5 * n and 1.5 * n tokens
        j = min(i + int(1.5 * n), len(tokens))
        while j > i + int(0.5 * n):
            # Decode the tokens and check for full stop or newline
            chunk = tokenizer.decode(tokens[i:j])
            if chunk.endswith(".") or chunk.endswith("\n"):
                break
            j -= 1
        # If no end of sentence found, use n tokens as the chunk size
        if j == i + int(0.5 * n):
            j = min(i + n, len(tokens))
        yield tokens[i:j]
        i = j



def extract_chunk(document, template_prompt):
    
    prompt=template_prompt.replace('<document>', document)

    input_ids = tokenizer.encode(prompt, return_tensors='pt')
    max_length = 1500

    sample_outputs = model.generate(input_ids,
                                    pad_token_id=tokenizer.eos_token_id,
                                    do_sample=True,
                                    max_length=max_length,
                                    min_length=max_length,
                                    top_k=1,
                                    num_beams=5,
                                    early_stopping=True,
                                    no_repeat_ngram_size=2,
                                    num_return_sequences=3)

    for i, sample_output in enumerate(sample_outputs):
        print(">> Generated text {}\n\n{}".format(i+1, tokenizer.decode(sample_output.tolist())))
        print('\n---')
    # response = openai.Completion.create(
    #     model='text-davinci-003', 
    #     prompt=prompt,
    #     temperature=0,
    #     max_tokens=1500,
    #     top_p=1,
    #     frequency_penalty=0,
    #     presence_penalty=0
    # )
    # return "1." + response['choices'][0]['text']    
# Initialise tokenizer
# tokenizer = tiktoken.get_encoding("cl100k_base")

results = []
    
chunks = create_chunks(clean_text, 1000, tokenizer)
text_chunks = [tokenizer.decode(chunk) for chunk in chunks]

for chunk in text_chunks:
    results.append(extract_chunk(chunk,template_prompt))
    print(chunk)
    print(results[-1])
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:63                                                                                   │
# │                                                                                                  │
# │   60 text_chunks = [tokenizer.decode(chunk) for chunk in chunks]                                 │
# │   61                                                                                             │
# │   62 for chunk in text_chunks:                                                                   │
# │ ❱ 63 │   results.append(extract_chunk(chunk,template_prompt))                                    │
# │   64 │   print(chunk)                                                                            │
# │   65 │   print(results[-1])                                                                      │
# ...

# %%
groups = [r.split('\n') for r in results]

# zip the groups together
zipped = list(zip(*groups))
zipped = [x for y in zipped for x in y if "Not specified" not in x and "__" not in x]
zipped
